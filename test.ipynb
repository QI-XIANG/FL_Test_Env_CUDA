# %%
import torch
import sys


# Check if GPU is available and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
df2
# Out:
#      FedAvg_Random_8.0_309
# 0                 0.044113
# 1                 0.067835
# 2                 0.080429
# 3                 0.097088
# 4                 0.115746
# ..                     ...
# 96                0.397415
# 97                0.399680
# 98                0.396282
# 99                0.402412
# 100               0.399547
#
# [101 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('code/results/Cifar100_20clients_100Round_DirOriginal/accuracy/FedAvg_Random_8.0_309.csv')
df2 = pd.read_csv('code/results/Cifar100_20clients_100Round_Dir1/accuracy/FedAvg_Random_8.0_309.csv')

# Plot the data x axis within 100 epochs
plt.plot(np.arange(101), df1['FedAvg_Random_8.0_309'], label='Dirichlet Alpha=0.1')
plt.plot(np.arange(101), df2['FedAvg_Random_8.0_309'], label='Dirichlet Alpha=1.0')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Cifar100 20 clients 100 Rounds 40% Poisoned Clients (FedAvg)')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('code/results/Cifar100_20clients_100Round_DirOriginal/loss/FedAvg_Random_8.0_309.csv')
df2 = pd.read_csv('code/results/Cifar100_20clients_100Round_Dir1/loss/FedAvg_Random_8.0_309.csv')

# Plot the data x axis within 100 epochs
plt.plot(np.arange(101), df1['FedAvg_Random_8.0_309'], label='Dirichlet Alpha=0.1')
plt.plot(np.arange(101), df2['FedAvg_Random_8.0_309'], label='Dirichlet Alpha=1.0')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Cifar100 20 clients 100 Rounds 40% Poisoned Clients (FedAvg)')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('code/results/MNIST_20clients_100Round_DirOriginal_Bulyan/accuracy/FedBulyan_Random_8.0_309.csv')
df2 = pd.read_csv('code/results/MNIST_20clients_100Round_DirOriginal_BulyanAdvanced/accuracy/FedBulyanAdvanced_Random_8.0_309.csv')
df3 = pd.read_csv('code/results/MNIST_20clients_100Round_DirOriginal_Krum/accuracy/FedKrum_Random_8.0_309.csv')

# Plot the data x axis within 100 epochs
plt.plot(np.arange(101), df1['FedBulyan_Random_8.0_309'], label='FedBulyan')
plt.plot(np.arange(101), df2['FedBulyanAdvanced_Random_8.0_309'], label='FedBulyan(Advanced)')
plt.plot(np.arange(101), df3['FedKrum_Random_8.0_309'], label='FedKrum')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('MNIST 20 clients 100 Rounds 40% Poisoned Clients')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('code/results/MNIST_20clients_100Round_DirOriginal_Bulyan/loss/FedBulyan_Random_8.0_309.csv')
df2 = pd.read_csv('code/results/MNIST_20clients_100Round_DirOriginal_BulyanAdvanced/loss/FedBulyanAdvanced_Random_8.0_309.csv')
df3 = pd.read_csv('code/results/MNIST_20clients_100Round_DirOriginal_Krum/loss/FedKrum_Random_8.0_309.csv')

# Plot the data x axis within 100 epochs
plt.plot(np.arange(101), df1['FedBulyan_Random_8.0_309'], label='FedBulyan')
plt.plot(np.arange(101), df2['FedBulyanAdvanced_Random_8.0_309'], label='FedBulyan(Advanced)')
plt.plot(np.arange(101), df3['FedKrum_Random_8.0_309'], label='FedKrum')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('MNIST 20 clients 100 Rounds 40% Poisoned Clients')
plt.legend()
plt.show()

# %%
print("Done")
